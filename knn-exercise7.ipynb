# %%
# We import necessary libraries
# Please do not use scikit-learn or any other package. Implement K-NN classification yourself.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statistics import mode

# %%
# Here we read the provided ushape.csv file
# We have retained only a small number of rows to ensure computational easiness and clear visualization
df = pd.read_csv('ushape.csv',names=['X','Y', 'C'], header=0)
df = df.drop(df.index[:50])
df = df.drop(df.index[:-10])

# %%
# Let us see how the data looks like
df.plot.scatter('X','Y',c='C', s=100, colormap='Dark2')
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
# This function implements the L2 distance between two sets of points
def l2(x1,y1, x2, y2):
    distance = np.sqrt((x1-x2)**2 + (y1-y2)**2)
    return distance

# %%
# The following function computes the distances between a test point and all the training points
def distance(x_test, y_test):
    distances = list()
    for index, row in df.iterrows():
        d = l2(row['X'], row['Y'], x_test, y_test)
        distances.append(d)
    return distances

# %%
# You need to complete the following function. 
# The following function should assign the class to a point (x_test, y_test) using K-NN classification
def knn_classification(x_test, y_test, k):
    distances=distance(x_test, y_test) #Calculate distances
    distances=np.array(distances) #Turn list into array

    classification=list()

    for i in range(len(x_test)):
        idxs=np.argsort(distances, axis=0)[:,i] #Sort distances to the model
        idxs=idxs[:k] #Choose index of knn
        classes=df['C'].iloc[idxs] #Find classification of knn
        classification.append(np.mean(classes)) #Decide classification by mode

        

    return classification

# %%
# You need to complete the following function.
# The following function should plot the decision surface for the two classes given the value of K.
# You need to test all the points between df.X.min() and df.X.max() and also df.Y.min() and df.Y.max().
def plot_decision_surface(k):
   cc=knn_classification(xx,yy,k) #Classify points
   numpy_data=np.array([xx, yy, cc]).T #Join nps
   newdf=pd.DataFrame(data=numpy_data, columns=['xx', 'yy','cc']) #Create df

   newdf.plot.scatter('xx','yy',c='cc', s=100, colormap='cool') #Plot

# %%
Xs=np.linspace(df.X.min(), df.X.max(), 100)
Ys=np.linspace(df.Y.min(), df.Y.max(), 100)

xx,yy = np.meshgrid(Xs,Ys)
xx=xx.flatten()
yy=yy.flatten()

# %%
plot_decision_surface(1)

# %%
plot_decision_surface(2)

# %%
plot_decision_surface(3)

# %%
# You need to complete the following function. 
# The following function should assign the class to a point (x_test, y_test) using K-NN classification
def knn_classification(x_test, y_test, k):
    distances=distance(x_test, y_test) #Calculate distances
    distances=np.array(distances) #Turn list into array

    classification=list()

    for i in range(len(x_test)):
        idxs=np.argsort(distances, axis=0)[:,i] #Sort distances to the model
        idxs=idxs[:k] #Choose index of knn
        classes=df['C'].iloc[idxs] #Find classification of knn
        classification.append(mode(classes)) #Decide classification by mode

        

    return classification

# %%
plot_decision_surface(1)

# %%
plot_decision_surface(3)

# %%
plot_decision_surface(5)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=690ec8c7-552c-4dd7-90ba-e9a7c3e912a7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
